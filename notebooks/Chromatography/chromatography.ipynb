# %%
import pandas as pd
import sys

sys.path.append('../../')
from src.transform import load_json
from src.plot_helpers import plot_experiment_range

indoors_cols = load_json("../../json/locations.json")["wings_indoors"]

# %% [markdown]
# ## Load Chromatography data

# %%
df_c = pd.read_csv('../../data/clean_data/hplc.csv',index_col=0,parse_dates=True)
df_c.rename(columns={'tvoc': 'hplc'}, inplace=True)

# in mg m3
df_c = df_c/1000

# %% [markdown]
# ## Load sensor data

# %% [markdown]
# ### ref sensor

# %%
df = pd.read_csv('../../data/clean_data/all_sensors.csv',index_col=0,parse_dates=True)

tvoc_full_mg = df[["tvoc_mg","sensor"]]
tvoc_full_mg.index.name = 'datetime'
tvoc_full_mg
# Out:
# /tmp/ipykernel_2064163/3288373119.py:1: DtypeWarning:
#
# Columns (6,25) have mixed types. Specify dtype option on import or set low_memory=False.
#                      tvoc_mg      sensor
# datetime
# 2024-10-11 13:24:18      NaN      inbiot
# 2024-10-11 13:33:57      NaN      inbiot
# 2024-10-11 13:43:57      NaN      inbiot
# 2024-10-11 13:44:34      NaN      inbiot
# 2024-10-11 13:54:27      NaN      inbiot
# ...                      ...         ...
# 2024-11-05 16:17:00     0.06  ref_sensor
# 2024-11-05 16:18:00     0.09  ref_sensor
# 2024-11-05 16:19:00     0.09  ref_sensor
# 2024-11-05 16:20:00     0.07  ref_sensor
# 2024-11-05 16:21:00     0.03  ref_sensor
#
# [964776 rows x 2 columns]

# %%
pivot_full = pd.DataFrame()

for col in tvoc_full_mg["sensor"].unique():
    
    pivot_full = pd.concat([pivot_full,tvoc_full_mg.loc[tvoc_full_mg['sensor'] == col].pivot_table(index='datetime', columns='sensor', values='tvoc_mg')],axis=1)

pivot_full.resample('240s').mean()['2024-10-16 05:00:43':'2024-10-20 23:56:17']
# Out:
# sensor               ref_sensor
# datetime
# 2024-10-16 05:04:00      7.4425
# 2024-10-16 05:08:00      7.4150
# 2024-10-16 05:12:00      7.4200
# 2024-10-16 05:16:00      7.4475
# 2024-10-16 05:20:00      7.4300
# ...                         ...
# 2024-10-20 23:40:00      8.3050
# 2024-10-20 23:44:00      8.3925
# 2024-10-20 23:48:00      8.3975
# 2024-10-20 23:52:00      8.5175
# 2024-10-20 23:56:00      8.5425
#
# [1724 rows x 1 columns]

# %%
ref_30_mean = pivot_full.resample('30min').mean()

# %% [markdown]
# ## Load thinnect

# %%
df_thinnect = pd.read_csv('../../data/thinnect_full.csv',index_col=0,parse_dates=True,low_memory=False)
df_thinnect.drop('sensor',axis=1,inplace=True)

df_thinnect.index = pd.to_datetime(df_thinnect.index)
df_thinnect = df_thinnect.sort_index()

df_thinnect.index.name = 'datetime'

df_thinnect.rename(columns={"tvoc_mg":"thinnect"},inplace=True)

df_thinnect['thinnect']['2024-10-29 11:13:00':'2024-10-29 14:58:00']
# Out:
# datetime
# 2024-10-29 11:15:00    0.031667
# 2024-10-29 11:30:00    0.027000
# 2024-10-29 11:45:00    0.043000
# 2024-10-29 12:00:00    0.034333
# 2024-10-29 12:15:00    0.049333
# 2024-10-29 12:30:00    0.051333
# 2024-10-29 12:45:00    0.096667
# 2024-10-29 13:00:00    0.100250
# 2024-10-29 13:15:00    0.138333
# 2024-10-29 13:30:00    0.144000
# 2024-10-29 13:45:00    0.163333
# 2024-10-29 14:00:00    0.133667
# 2024-10-29 14:15:00    0.120500
# 2024-10-29 14:30:00    0.098333
# 2024-10-29 14:45:00    0.128000
# Name: thinnect, dtype: float64

# %% [markdown]
# ## Analysis

# %%
sensors = pd.concat([ref_30_mean['2024-10-29 11:13:00':'2024-10-29 14:58:00'],df_thinnect['2024-10-29 11:13:00':'2024-10-29 14:58:00']["thinnect"]],axis=1)
full_df = pd.concat([sensors,df_c],axis=1)

# %%
full_df
# Out:
#                      ref_sensor  thinnect      hplc
# datetime
# 2024-10-29 11:13:00         NaN       NaN  0.046236
# 2024-10-29 11:14:00         NaN       NaN  0.043901
# 2024-10-29 11:15:00         NaN  0.031667       NaN
# 2024-10-29 11:30:00    1.537667  0.027000       NaN
# 2024-10-29 11:45:00         NaN  0.043000       NaN
# 2024-10-29 11:47:00         NaN       NaN  0.209815
# 2024-10-29 11:55:00         NaN       NaN  0.069578
# 2024-10-29 12:00:00    1.903000  0.034333       NaN
# 2024-10-29 12:15:00         NaN  0.049333       NaN
# 2024-10-29 12:30:00    3.290667  0.051333       NaN
# 2024-10-29 12:37:00         NaN       NaN  0.279627
# 2024-10-29 12:45:00         NaN  0.096667       NaN
# 2024-10-29 13:00:00    2.698667  0.100250  0.008169
# 2024-10-29 13:15:00         NaN  0.138333       NaN
# 2024-10-29 13:30:00    1.967667  0.144000       NaN
# 2024-10-29 13:32:00         NaN       NaN  0.040150
# 2024-10-29 13:45:00         NaN  0.163333       NaN
# 2024-10-29 14:00:00    1.511000  0.133667       NaN
# 2024-10-29 14:15:00         NaN  0.120500       NaN
# 2024-10-29 14:26:00         NaN       NaN  0.534548
# 2024-10-29 14:30:00    2.702000  0.098333       NaN
# 2024-10-29 14:45:00         NaN  0.128000       NaN
# 2024-10-29 14:58:00         NaN       NaN  0.067792

# %%
plot_experiment_range(df=full_df['2024-10-29 11:13:00':'2024-10-29 14:58:00'].resample('30min').mean(),col_names=['ref_sensor','thinnect','hplc'],start_date='2024-10-29 11:13:00',end_date='2024-10-29 14:58:00')
# Out:
# <div>                            <div id="d1cc2756-7f6c-470a-b14a-16212c8b2508" class="plotly-graph-div" style="height:700px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d1cc2756-7f6c-470a-b14a-16212c8b2508")) {                    Plotly.newPlot(                        "d1cc2756-7f6c-470a-b14a-16212c8b2508",                        [{"mode":"lines","name":"ref_sensor","x":["2024-10-29T11:00:00","2024-10-29T11:30:00","2024-10-29T12:00:00","2024-10-29T12:30:00","2024-10-29T13:00:00","2024-10-29T13:30:00","2024-10-29T14:00:00","2024-10-29T14:30:00"],"y":[null,1.5376666666666667,1.903,3.2906666666666666,2.6986666666666665,1.9676666666666667,1.511,2.702],"type":"scatter"},{"mode":"lines","name":"thinnect","x":["2024-10-29T11:00:00","2024-10-29T11:30:00","2024-10-29T12:00:00","2024-10-29T12:30:00","2024-10-29T13:00:00","2024-10-29T13:30:00","2024-10-29T14:00:00","2024-10-29T14:30:00"],"y":[0.0316666666666666,0.034999999999999996,0.0418333333333333,0.07399999999999995,0.11929166666666666,0.15366666666666665,0.1270833333333333,0.11316666666666665],"type":"scatter"},{"mode":"lines","name":"hplc","x":["2024-10-29T11:00:00","2024-10-29T11:30:00","2024-10-29T12:00:00","2024-10-29T12:30:00","2024-10-29T13:00:00","2024-10-29T13:30:00","2024-10-29T14:00:00","2024-10-29T14:30:00"],"y":[0.0450685,0.1396965,null,0.279627,0.008169000000000001,0.040150000000000005,0.5345480000000001,0.06779200000000002],"type":"scatter"},{"fill":"toself","fillcolor":"rgba(0, 255, 255, 0.3)","line":{"color":"rgba(255, 255, 255, 0)"},"name":"VOC Tubes - Car","x":["2024-10-29 11:02","2024-10-29 11:02","2024-10-29 11:22","2024-10-29 11:22"],"y":[0.008169000000000001,3.2906666666666666,3.2906666666666666,0.008169000000000001],"type":"scatter"},{"fill":"toself","fillcolor":"rgba(0, 255, 255, 0.3)","line":{"color":"rgba(255, 255, 255, 0)"},"name":"VOC Tubes - Car","x":["2024-10-29 11:46","2024-10-29 11:46","2024-10-29 11:56","2024-10-29 11:56"],"y":[0.008169000000000001,3.2906666666666666,3.2906666666666666,0.008169000000000001],"type":"scatter"},{"fill":"toself","fillcolor":"rgba(0, 255, 255, 0.3)","line":{"color":"rgba(255, 255, 255, 0)"},"name":"VOC Tubes - Diffuser (Oil)","x":["2024-10-29 12:28","2024-10-29 12:28","2024-10-29 12:52","2024-10-29 12:52"],"y":[0.008169000000000001,3.2906666666666666,3.2906666666666666,0.008169000000000001],"type":"scatter"},{"fill":"toself","fillcolor":"rgba(0, 255, 255, 0.3)","line":{"color":"rgba(255, 255, 255, 0)"},"name":"VOC Tubes - Diffuser (Oil)","x":["2024-10-29 12:52","2024-10-29 12:52","2024-10-29 13:07","2024-10-29 13:07"],"y":[0.008169000000000001,3.2906666666666666,3.2906666666666666,0.008169000000000001],"type":"scatter"},{"fill":"toself","fillcolor":"rgba(255, 69, 0, 0.3)","line":{"color":"rgba(255, 255, 255, 0)"},"name":"VOC Tubes - Gas Burner","x":["2024-10-29 13:24","2024-10-29 13:24","2024-10-29 13:39","2024-10-29 13:39"],"y":[0.008169000000000001,3.2906666666666666,3.2906666666666666,0.008169000000000001],"type":"scatter"},{"fill":"toself","fillcolor":"rgba(255, 165, 0, 0.3)","line":{"color":"rgba(255, 255, 255, 0)"},"name":"VOC Tubes - Candle","x":["2024-10-29 14:20","2024-10-29 14:20","2024-10-29 14:51","2024-10-29 14:51"],"y":[0.008169000000000001,3.2906666666666666,3.2906666666666666,0.008169000000000001],"type":"scatter"},{"fill":"toself","fillcolor":"rgba(255, 165, 0, 0.3)","line":{"color":"rgba(255, 255, 255, 0)"},"name":"VOC Tubes - Candle","x":["2024-10-29 14:51","2024-10-29 14:51","2024-10-29 15:06","2024-10-29 15:06"],"y":[0.008169000000000001,3.2906666666666666,3.2906666666666666,0.008169000000000001],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#4603 ...
